# %%
import pandas as pd

# Replace 'your_file_path' with the actual path to your CSV file
file_path = "/Users/arka_bagchi/Desktop/AirDNA/filtered_data.tsv/Joshua_Tree_AirDNA.csv"

# Load the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, sep='\t')  # Assuming the file is tab-separated

# Display the first few rows of the DataFrame to verify the data is loaded
df.head()
# Out:
#     Longitude  Has Parking  Airbnb Communication Rating  \
# 0 -116.307012         True                          9.0
# 1 -116.446580         True                         10.0
# 2 -116.314960         True                         10.0
# 3 -116.395860         True                         10.0
# 4 -116.335195         True                         10.0
#
#    Revenue Potential LTM        Property Type  \
# 0                    NaN                House
# 1                41092.0             Bungalow
# 2                    NaN            Townhouse
# 3                66374.0                House
# 4                    NaN  Condominium (condo)
#
#                                       Listing Images  Has Hot Tub  \
# 0  \[\"\"https://a2.muscache.com/im/pictures/a715...        False
# 1  \[\"\"https://a0.muscache.com/im/pictures/2ea2...         True
# 2  \[\"\"https://a0.muscache.com/im/pictures/1507...         True
# 3  \[\"\"https://a0.muscache.com/im/pictures/miso...         True
# ...

# %%
# Display column names and data types
column_data_types = df.dtypes
column_data_types
# Out:
# Longitude                        float64
# Has Parking                         bool
# Airbnb Communication Rating      float64
# Revenue Potential LTM            float64
# Property Type                     object
# Listing Images                    object
# Has Hot Tub                         bool
# Country                           object
# City                              object
# Bedrooms                         float64
# Airbnb Accuracy Rating           float64
# Published Weekly Rate            float64
# Neighborhood                      object
# Airbnb Location Rating           float64
# ADR                              float64
# Response Rate                    float64
# Published Monthly Rate           float64
# Pets Allowed                        bool
# Occupancy Rate LTM               float64
# Max Guests                       float64
# Listing Type                      object
# Host Type                         object
# Has Pool                            bool
# ...

# %%
# Show missing values for each column
missing_values = df.isnull().sum()
missing_values
# Out:
# Longitude                            0
# Has Parking                          0
# Airbnb Communication Rating       7505
# Revenue Potential LTM             7651
# Property Type                       11
# Listing Images                     357
# Has Hot Tub                          0
# Country                              0
# City                                 0
# Bedrooms                           197
# Airbnb Accuracy Rating            7504
# Published Weekly Rate            10311
# Neighborhood                     14593
# Airbnb Location Rating            7510
# ADR                               7651
# Response Rate                     2851
# Published Monthly Rate           10310
# Pets Allowed                         0
# Occupancy Rate LTM                7651
# Max Guests                           5
# Listing Type                         2
# Host Type                            0
# Has Pool                             0
# Created Date                         0
# ...

# %%
# Calculate the proportion of missing values for each column
missing_proportion = (df.isnull().sum() / len(df)) * 100
missing_proportion
# Out:
# Longitude                         0.000000
# Has Parking                       0.000000
# Airbnb Communication Rating      43.122271
# Revenue Potential LTM            43.961158
# Property Type                     0.063204
# Listing Images                    2.051253
# Has Hot Tub                       0.000000
# Country                           0.000000
# City                              0.000000
# Bedrooms                          1.131924
# Airbnb Accuracy Rating           43.116525
# Published Weekly Rate            59.245001
# Neighborhood                     83.848541
# Airbnb Location Rating           43.151000
# ADR                              43.961158
# Response Rate                    16.381292
# Published Monthly Rate           59.239255
# Pets Allowed                      0.000000
# Occupancy Rate LTM               43.961158
# Max Guests                        0.028729
# Listing Type                      0.011492
# Host Type                         0.000000
# ...

# %%
# List of columns to drop
columns_to_drop = ['Listing Images', 'Revenue Potential LTM', 'Neighborhood', 'Airbnb Location Rating', 'Exact Location', 'Currency']

# Drop the columns
df = df.drop(columns=columns_to_drop)

# Display the updated DataFrame
df.head()
# Out:
#     Longitude  Has Parking  Airbnb Communication Rating        Property Type  \
# 0 -116.307012         True                          9.0                House
# 1 -116.446580         True                         10.0             Bungalow
# 2 -116.314960         True                         10.0            Townhouse
# 3 -116.395860         True                         10.0                House
# 4 -116.335195         True                         10.0  Condominium (condo)
#
#    Has Hot Tub        Country          City  Bedrooms  Airbnb Accuracy Rating  \
# 0        False  United States   Palm Desert       3.0                     9.0
# 1         True  United States       Landers       1.0                    10.0
# 2         True  United States   Palm Desert       2.0                     9.0
# 3         True  United States  Yucca Valley       1.0                    10.0
# 4         True  United States   Palm Desert       3.0                    10.0
#
# ...

# %%
# List of columns
columns_list = df.columns.tolist()

# Number of columns
num_columns = len(columns_list)

columns_list, num_columns
# Out:
# (['Longitude',
#   'Has Parking',
#   'Airbnb Communication Rating',
#   'Property Type',
#   'Has Hot Tub',
#   'Country',
#   'City',
#   'Bedrooms',
#   'Airbnb Accuracy Rating',
#   'Published Weekly Rate',
#   'ADR',
#   'Response Rate',
#   'Published Monthly Rate',
#   'Pets Allowed',
#   'Occupancy Rate LTM',
#   'Max Guests',
#   'Listing Type',
#   'Host Type',
#   'Has Pool',
#   'Created Date',
#   'Bathrooms',
#   'Property ID',
#   'Overall Rating',
#   'Minimum Stay',
#   'Location Type',
#   'Cleaning Fee',
#   'Price Tier',
#   'Has Kitchen',
#   'Count Reservation Days LTM',
#   'Airbnb Checkin Rating',
#   'Number of Reviews',
#   'Number of Photos',
#   'Number of Bookings LTM',
#   'Latitude',
#   'Extra People Fee',
#   'Count Blocked Days LTM',
#   'Count Available Days LTM',
#   'Zipcode',
#   'State',
#   'Revenue LTM',
#   'Has Air Con',
#   'Airbnb Value Rating',
#   'Published Nightly Rate',
#   'Last Scraped Date',
#   'Metropolitan Statistical Area',
# ...

# %%
# List of columns
columns_list = df.columns.tolist()

# Number of columns
num_columns = len(columns_list)

columns_list, num_columns
# Out:
# (['Longitude',
#   'Has Parking',
#   'Airbnb Communication Rating',
#   'Property Type',
#   'Has Hot Tub',
#   'Country',
#   'City',
#   'Bedrooms',
#   'Airbnb Accuracy Rating',
#   'Published Weekly Rate',
#   'ADR',
#   'Response Rate',
#   'Published Monthly Rate',
#   'Pets Allowed',
#   'Occupancy Rate LTM',
#   'Max Guests',
#   'Listing Type',
#   'Host Type',
#   'Has Pool',
#   'Created Date',
#   'Bathrooms',
#   'Property ID',
#   'Overall Rating',
#   'Minimum Stay',
#   'Location Type',
#   'Cleaning Fee',
#   'Price Tier',
#   'Has Kitchen',
#   'Count Reservation Days LTM',
#   'Airbnb Checkin Rating',
#   'Number of Reviews',
#   'Number of Photos',
#   'Number of Bookings LTM',
#   'Latitude',
#   'Extra People Fee',
#   'Count Blocked Days LTM',
#   'Count Available Days LTM',
#   'Zipcode',
#   'State',
#   'Revenue LTM',
#   'Has Air Con',
#   'Airbnb Value Rating',
#   'Published Nightly Rate',
#   'Last Scraped Date',
#   'Metropolitan Statistical Area',
# ...

# %%
# Specify the selected columns
selected_columns = [
    'Longitude', 'Has Parking', 'Airbnb Communication Rating', 'Property Type',
    'Has Hot Tub', 'Country', 'City', 'Bedrooms', 'Airbnb Accuracy Rating',
    'Published Weekly Rate', 'Pets Allowed', 'Occupancy Rate LTM', 'Max Guests',
    'Listing Type', 'Host Type', 'Has Pool', 'Bathrooms', 'Property ID',
    'Overall Rating', 'Minimum Stay', 'Location Type', 'Cleaning Fee',
    'Price Tier', 'Has Kitchen', 'Count Reservation Days LTM',
    'Airbnb Checkin Rating', 'Number of Reviews', 'Number of Photos',
    'Number of Bookings LTM', 'Latitude', 'Extra People Fee',
    'Count Blocked Days LTM', 'Count Available Days LTM', 'Zipcode', 'State',
    'Has Air Con', 'Airbnb Value Rating', 'Published Nightly Rate',
    'Metropolitan Statistical Area', 'Has Gym', 'Airbnb Superhost',
    'Real Estate Property Type', 'Instantbook', 'Airbnb Cleanliness Rating'
]

# Save the selected columns from the original DataFrame to a CSV file
df[selected_columns].to_csv('/Users/arka_bagchi/Desktop/AirDNA/JoshuaTree_Dataset_Reduced_Columns.csv', index=False)

# %%
import pandas as pd

# Define the file path
file_path = '/Users/arka_bagchi/Desktop/AirDNA/JoshuaTree_Dataset_Reduced_Columns.csv'

# Load the CSV file into a DataFrame
imported_df = pd.read_csv(file_path)

# Check the shape of the DataFrame
shape = imported_df.shape

# Display the first few rows of the imported DataFrame
head = imported_df.head()

(shape, head)
# Out:
# ((17404, 44),
#      Longitude  Has Parking  Airbnb Communication Rating        Property Type  \
#  0 -116.307012         True                          9.0                House
#  1 -116.446580         True                         10.0             Bungalow
#  2 -116.314960         True                         10.0            Townhouse
#  3 -116.395860         True                         10.0                House
#  4 -116.335195         True                         10.0  Condominium (condo)
#
#     Has Hot Tub        Country          City  Bedrooms  Airbnb Accuracy Rating  \
#  0        False  United States   Palm Desert       3.0                     9.0
#  1         True  United States       Landers       1.0                    10.0
#  2         True  United States   Palm Desert       2.0                     9.0
#  3         True  United States  Yucca Valley       1.0                    10.0
#  4         True  United States   Palm Desert       3.0                    10.0
#
# ...

# %%
num_columns = len(imported_df.columns)
num_columns
# Out:
# 44

# %%
imported_df.columns
# Out:
# Index(['Longitude', 'Has Parking', 'Airbnb Communication Rating',
#        'Property Type', 'Has Hot Tub', 'Country', 'City', 'Bedrooms',
#        'Airbnb Accuracy Rating', 'Published Weekly Rate', 'Pets Allowed',
#        'Occupancy Rate LTM', 'Max Guests', 'Listing Type', 'Host Type',
#        'Has Pool', 'Bathrooms', 'Property ID', 'Overall Rating',
#        'Minimum Stay', 'Location Type', 'Cleaning Fee', 'Price Tier',
#        'Has Kitchen', 'Count Reservation Days LTM', 'Airbnb Checkin Rating',
#        'Number of Reviews', 'Number of Photos', 'Number of Bookings LTM',
#        'Latitude', 'Extra People Fee', 'Count Blocked Days LTM',
#        'Count Available Days LTM', 'Zipcode', 'State', 'Has Air Con',
#        'Airbnb Value Rating', 'Published Nightly Rate',
#        'Metropolitan Statistical Area', 'Has Gym', 'Airbnb Superhost',
#        'Real Estate Property Type', 'Instantbook',
#        'Airbnb Cleanliness Rating'],
#       dtype='object')

# %%
# List of columns
columns_list = df.columns.tolist()

# Number of columns
num_columns = len(columns_list)

columns_list, num_columns
# Out:
# (['Longitude',
#   'Has Parking',
#   'Airbnb Communication Rating',
#   'Property Type',
#   'Has Hot Tub',
#   'Country',
#   'City',
#   'Bedrooms',
#   'Airbnb Accuracy Rating',
#   'Published Weekly Rate',
#   'ADR',
#   'Response Rate',
#   'Published Monthly Rate',
#   'Pets Allowed',
#   'Occupancy Rate LTM',
#   'Max Guests',
#   'Listing Type',
#   'Host Type',
#   'Has Pool',
#   'Created Date',
#   'Bathrooms',
#   'Property ID',
#   'Overall Rating',
#   'Minimum Stay',
#   'Location Type',
#   'Cleaning Fee',
#   'Price Tier',
#   'Has Kitchen',
#   'Count Reservation Days LTM',
#   'Airbnb Checkin Rating',
#   'Number of Reviews',
#   'Number of Photos',
#   'Number of Bookings LTM',
#   'Latitude',
#   'Extra People Fee',
#   'Count Blocked Days LTM',
#   'Count Available Days LTM',
#   'Zipcode',
#   'State',
#   'Revenue LTM',
#   'Has Air Con',
#   'Airbnb Value Rating',
#   'Published Nightly Rate',
#   'Last Scraped Date',
#   'Metropolitan Statistical Area',
# ...

# %%
# List of columns to drop
columns_to_drop = ['Listing Images', 'Revenue Potential LTM', 'Neighborhood', 'Airbnb Location Rating', 'Exact Location', 'Currency']

# Filter columns that exist in the DataFrame
columns_to_drop = [col for col in columns_to_drop if col in df.columns]

# Create a new DataFrame without the specified columns
new_df = df.drop(columns=columns_to_drop)

# %%
# Check the number of columns in new_df
num_columns = len(new_df.columns)

# Get the names of columns in new_df
column_names = new_df.columns.tolist()

num_columns, column_names
# Out:
# (50,
#  ['Longitude',
#   'Has Parking',
#   'Airbnb Communication Rating',
#   'Property Type',
#   'Has Hot Tub',
#   'Country',
#   'City',
#   'Bedrooms',
#   'Airbnb Accuracy Rating',
#   'Published Weekly Rate',
#   'ADR',
#   'Response Rate',
#   'Published Monthly Rate',
#   'Pets Allowed',
#   'Occupancy Rate LTM',
#   'Max Guests',
#   'Listing Type',
#   'Host Type',
#   'Has Pool',
#   'Created Date',
#   'Bathrooms',
#   'Property ID',
#   'Overall Rating',
#   'Minimum Stay',
#   'Location Type',
#   'Cleaning Fee',
#   'Price Tier',
#   'Has Kitchen',
#   'Count Reservation Days LTM',
#   'Airbnb Checkin Rating',
#   'Number of Reviews',
#   'Number of Photos',
#   'Number of Bookings LTM',
#   'Latitude',
#   'Extra People Fee',
#   'Count Blocked Days LTM',
#   'Count Available Days LTM',
#   'Zipcode',
#   'State',
#   'Revenue LTM',
#   'Has Air Con',
#   'Airbnb Value Rating',
#   'Published Nightly Rate',
#   'Last Scraped Date',
# ...

# %%
# Specify the file path
file_path = "/Users/arka_bagchi/Desktop/AirDNA/JoshuaTree_Reduced_Columns.csv"

# Save the DataFrame to a CSV file
new_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Specify the file path
file_path = "/Users/arka_bagchi/Desktop/AirDNA/JoshuaTree_Reduced_Columns.csv"

# Load the CSV into a DataFrame
loaded_df = pd.read_csv(file_path)

# Get the column names
column_names = loaded_df.columns.tolist()

# Get the number of columns
num_columns = len(column_names)

# Get the shape of the DataFrame
data_shape = loaded_df.shape

column_names, num_columns, data_shape
# Out:
# (['Longitude',
#   'Has Parking',
#   'Airbnb Communication Rating',
#   'Property Type',
#   'Has Hot Tub',
#   'Country',
#   'City',
#   'Bedrooms',
#   'Airbnb Accuracy Rating',
#   'Published Weekly Rate',
#   'ADR',
#   'Response Rate',
#   'Published Monthly Rate',
#   'Pets Allowed',
#   'Occupancy Rate LTM',
#   'Max Guests',
#   'Listing Type',
#   'Host Type',
#   'Has Pool',
#   'Created Date',
#   'Bathrooms',
#   'Property ID',
#   'Overall Rating',
#   'Minimum Stay',
#   'Location Type',
#   'Cleaning Fee',
#   'Price Tier',
#   'Has Kitchen',
#   'Count Reservation Days LTM',
#   'Airbnb Checkin Rating',
#   'Number of Reviews',
#   'Number of Photos',
#   'Number of Bookings LTM',
#   'Latitude',
#   'Extra People Fee',
#   'Count Blocked Days LTM',
#   'Count Available Days LTM',
#   'Zipcode',
#   'State',
#   'Revenue LTM',
#   'Has Air Con',
#   'Airbnb Value Rating',
#   'Published Nightly Rate',
#   'Last Scraped Date',
#   'Metropolitan Statistical Area',
# ...
